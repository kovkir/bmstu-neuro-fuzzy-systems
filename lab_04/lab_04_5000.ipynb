# %% [markdown]
# # Лабораторная работа 4

# %% [markdown]
# Плотные нейронные сети
#
# Набор базовых данных о биологических сигналах здоровья.
# Цель состоит в том, чтобы определить наличие или отсутствие курения с помощью биосигналов.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
dfInit = pd.read_csv('./smoking_5000.csv', delimiter=',', encoding='utf8')
del dfInit["ID"]
df = dfInit.copy(deep=True)
df
# Out:
#      gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0         F   40         155          60       81.3             1.2
# 1         F   40         160          60       81.0             0.8
# 2         M   55         170          60       80.0             0.8
# 3         M   40         165          70       88.0             1.5
# 4         F   40         155          60       86.0             1.0
# ...     ...  ...         ...         ...        ...             ...
# 4995      F   40         145          50       65.6             1.2
# 4996      M   30         175          60       81.0             1.0
# 4997      F   60         145          40       72.0             0.3
# 4998      M   20         175          85       91.0             0.9
# 4999      F   40         170          70       85.0             1.0
#
#       eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0                 1.0            1.0             1.0     114.0        73.0
# 1                 0.6            1.0             1.0     119.0        70.0
# 2                 0.8            1.0             1.0     138.0        86.0
# 3                 1.5            1.0             1.0     100.0        60.0
# 4                 1.0            1.0             1.0     120.0        74.0
# ...               ...            ...             ...       ...         ...
# 4995              1.2            1.0             1.0     108.0        64.0
# 4996              1.2            1.0             1.0     119.0        70.0
# 4997              0.6            1.0             1.0     136.0        80.0
# 4998              1.2            1.0             1.0     135.0        94.0
# 4999              1.2            1.0             1.0     125.0        82.0
#
#       fasting blood sugar  Cholesterol  triglyceride   HDL    LDL  hemoglobin  \
# 0                    94.0        215.0          82.0  73.0  126.0        12.9
# 1                   130.0        192.0         115.0  42.0  127.0        12.7
# 2                    89.0        242.0         182.0  55.0  151.0        15.8
# 3                    96.0        322.0         254.0  45.0  226.0        14.7
# 4                    80.0        184.0          74.0  62.0  107.0        12.5
# ...                   ...          ...           ...   ...    ...         ...
# 4995                 91.0        192.0          55.0  88.0   93.0        13.8
# 4996                 93.0        145.0          65.0  55.0   77.0        14.9
# 4997                101.0        211.0         146.0  52.0  130.0        12.5
# 4998                110.0        209.0         134.0  64.0  117.0        15.8
# 4999                110.0        209.0          67.0  80.0  116.0        13.0
#
#       Urine protein  serum creatinine   AST   ALT    Gtp oral  dental caries  \
# 0               1.0               0.7  18.0  19.0   27.0    Y              0
# 1               1.0               0.6  22.0  19.0   18.0    Y              0
# 2               1.0               1.0  21.0  16.0   22.0    Y              0
# 3               1.0               1.0  19.0  26.0   18.0    Y              0
# 4               1.0               0.6  16.0  14.0   22.0    Y              0
# ...             ...               ...   ...   ...    ...  ...            ...
# 4995            1.0               0.9  19.0  11.0   13.0    Y              0
# 4996            1.0               1.1  18.0  13.0   27.0    Y              0
# 4997            1.0               0.5  23.0  16.0   12.0    Y              0
# 4998            1.0               1.0  29.0  45.0  146.0    Y              1
# 4999            1.0               0.7  25.0  16.0   18.0    Y              0
#
#      tartar  smoking
# 0         Y        0
# 1         Y        0
# 2         N        1
# 3         Y        0
# 4         N        0
# ...     ...      ...
# 4995      N        0
# 4996      Y        0
# 4997      Y        0
# 4998      N        1
# 4999      N        0
#
# [5000 rows x 26 columns]

# %% [markdown]
# #### Преобразование параметров

# %%
def updateData(fieldName):
    dataDf = list(set(df[fieldName].map(lambda elem: elem)))

    cnt = 0
    dataDict = {}
    for shape in dataDf:
        if shape not in dataDict.keys():
            dataDict[shape] = cnt
            cnt += 1
        
    print(f"{fieldName} = {dataDict}\n")

    df[fieldName] = df[fieldName].map(lambda elem: dataDict[elem])

# %%
df.dropna(axis=0, inplace=True)

updateData(fieldName="gender")
updateData(fieldName="oral")
updateData(fieldName="tartar")

df
# Out:
# gender = {'M': 0, 'F': 1}
#
# oral = {'Y': 0}
#
# tartar = {'Y': 0, 'N': 1}
#       gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          1   40         155          60       81.3             1.2
# 1          1   40         160          60       81.0             0.8
# 2          0   55         170          60       80.0             0.8
# 3          0   40         165          70       88.0             1.5
# 4          1   40         155          60       86.0             1.0
# ...      ...  ...         ...         ...        ...             ...
# 4995       1   40         145          50       65.6             1.2
# 4996       0   30         175          60       81.0             1.0
# 4997       1   60         145          40       72.0             0.3
# 4998       0   20         175          85       91.0             0.9
# 4999       1   40         170          70       85.0             1.0
#
#       eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0                 1.0            1.0             1.0     114.0        73.0
# 1                 0.6            1.0             1.0     119.0        70.0
# 2                 0.8            1.0             1.0     138.0        86.0
# 3                 1.5            1.0             1.0     100.0        60.0
# 4                 1.0            1.0             1.0     120.0        74.0
# ...               ...            ...             ...       ...         ...
# 4995              1.2            1.0             1.0     108.0        64.0
# 4996              1.2            1.0             1.0     119.0        70.0
# 4997              0.6            1.0             1.0     136.0        80.0
# 4998              1.2            1.0             1.0     135.0        94.0
# 4999              1.2            1.0             1.0     125.0        82.0
#
#       fasting blood sugar  Cholesterol  triglyceride   HDL    LDL  hemoglobin  \
# 0                    94.0        215.0          82.0  73.0  126.0        12.9
# 1                   130.0        192.0         115.0  42.0  127.0        12.7
# 2                    89.0        242.0         182.0  55.0  151.0        15.8
# 3                    96.0        322.0         254.0  45.0  226.0        14.7
# 4                    80.0        184.0          74.0  62.0  107.0        12.5
# ...                   ...          ...           ...   ...    ...         ...
# 4995                 91.0        192.0          55.0  88.0   93.0        13.8
# 4996                 93.0        145.0          65.0  55.0   77.0        14.9
# 4997                101.0        211.0         146.0  52.0  130.0        12.5
# 4998                110.0        209.0         134.0  64.0  117.0        15.8
# 4999                110.0        209.0          67.0  80.0  116.0        13.0
#
#       Urine protein  serum creatinine   AST   ALT    Gtp  oral  dental caries  \
# 0               1.0               0.7  18.0  19.0   27.0     0              0
# 1               1.0               0.6  22.0  19.0   18.0     0              0
# 2               1.0               1.0  21.0  16.0   22.0     0              0
# 3               1.0               1.0  19.0  26.0   18.0     0              0
# 4               1.0               0.6  16.0  14.0   22.0     0              0
# ...             ...               ...   ...   ...    ...   ...            ...
# 4995            1.0               0.9  19.0  11.0   13.0     0              0
# 4996            1.0               1.1  18.0  13.0   27.0     0              0
# 4997            1.0               0.5  23.0  16.0   12.0     0              0
# 4998            1.0               1.0  29.0  45.0  146.0     0              1
# 4999            1.0               0.7  25.0  16.0   18.0     0              0
#
#       tartar  smoking
# 0          0        0
# 1          0        0
# 2          1        1
# 3          0        0
# 4          1        0
# ...      ...      ...
# 4995       1        0
# 4996       0        0
# 4997       0        0
# 4998       1        1
# 4999       1        0
#
# [5000 rows x 26 columns]

# %% [markdown]
# #### Разделение на обучающие и тестовые данные

# %%
x = df.drop(['smoking'], axis=1)
y = df['smoking']

xTraining, xTest, yTraining, yTest = train_test_split(x, y, test_size = 0.3, random_state=42)

# %%
scaler = StandardScaler()
scaler.fit(xTraining)
xTrainingTransf = scaler.transform(xTraining)
xTestTransf = scaler.transform(xTest)

# %% [markdown]
# #### Многослойный перцептрон

# %%
def calculateAccuracy(mlpcClf: MLPClassifier):
    mlpcClf.fit(xTrainingTransf, yTraining)
    return mlpcClf.score(xTestTransf, yTest)

# %% [markdown]
# Количество нейронов на 1 уровне

# %%
hiddenLayerSizeArr = [(60,), (100,), (150,), (200,), (250,), (350,), (500,), (750,), (1000,)]

# activation=relu, solver=lbfgs, max_iter=200

for layerSize in hiddenLayerSizeArr:
    mlpcClf = MLPClassifier(
        solver='lbfgs',
        hidden_layer_sizes=layerSize, 
        early_stopping=True,
        random_state=42
    )
    
    print('layerSize={0}, accuracy={1}'.format(layerSize, calculateAccuracy(mlpcClf)))
# Out:
# /Users/kirill/Documents/bmstu/neuro_fuzzy_systems/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# layerSize=(60,), accuracy=0.6926666666666667
# /Users/kirill/Documents/bmstu/neuro_fuzzy_systems/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# layerSize=(100,), accuracy=0.6893333333333334
# layerSize=(150,), accuracy=0.696
# layerSize=(200,), accuracy=0.69
# layerSize=(250,), accuracy=0.6873333333333334
# layerSize=(350,), accuracy=0.676
# layerSize=(500,), accuracy=0.7046666666666667
# layerSize=(750,), accuracy=0.7033333333333334
# layerSize=(1000,), accuracy=0.6853333333333333

# %% [markdown]
# Оптимизатор

# %%
solverArr = ['lbfgs', 'sgd', 'adam']

# activation=relu, max_iter=200
# 'lbfgs' -- для маленьких датасетов
# 'sgd' -- стохастический градиентный спуск
# 'adam' -- для больших датасетов

for solver in solverArr:
    mlpcClf = MLPClassifier(
        solver=solver,
        hidden_layer_sizes=(150,), 
        early_stopping=True,
        random_state=42
    )
    
    print('solver={0}, accuracy={1}'.format(solver, calculateAccuracy(mlpcClf)))
# Out:
# solver=lbfgs, accuracy=0.696
# solver=sgd, accuracy=0.714
# solver=adam, accuracy=0.7553333333333333

# %% [markdown]
# Функция активации

# %%
fArr = ['identity', 'logistic', 'tanh', 'relu']

# max_iter=200

for f in fArr:
    mlpcClf = MLPClassifier(
        activation=f,
        solver='lbfgs',
        hidden_layer_sizes=(150,), 
        early_stopping=True,
        random_state=42
    )
    
    print('f={0}, accuracy={1}'.format(f, calculateAccuracy(mlpcClf)))
# Out:
# f=identity, accuracy=0.7413333333333333
# /Users/kirill/Documents/bmstu/neuro_fuzzy_systems/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# f=logistic, accuracy=0.704
# f=tanh, accuracy=0.6966666666666667
# f=relu, accuracy=0.696

# %% [markdown]
# Число итераций

# %%
iterArr = [200, 500, 700, 1000]

for iter in iterArr:
    mlpcClf = MLPClassifier(
        activation='relu',
        solver='lbfgs',
        hidden_layer_sizes=(150,), 
        early_stopping=True,
        random_state=42,
        max_iter=iter
    )
    
    print('max_iter={0}, accuracy={1}'.format(iter, calculateAccuracy(mlpcClf)))
# Out:
# max_iter=200, accuracy=0.696
# max_iter=500, accuracy=0.696
# max_iter=700, accuracy=0.696
# max_iter=1000, accuracy=0.696

# %% [markdown]
# Итоговый результат

# %%
mlpcClf = MLPClassifier(
    activation='relu',
    solver='lbfgs',
    hidden_layer_sizes=(150,), 
    early_stopping=True,
    random_state=42,
    max_iter=200
)

print('accuracy={0}'.format(calculateAccuracy(mlpcClf)))
# Out:
# accuracy=0.696

# %%
classes_names = ['0','1']
cm = pd.DataFrame(
    confusion_matrix(yTest, mlpcClf.predict(xTestTransf)), 
    columns=classes_names, 
    index=classes_names
)
                  
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
